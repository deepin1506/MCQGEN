# %%
import os   
import json
import pandas as pd
import traceback

# %%
# %pip install langchain-openai
# Out:
# Collecting langchain-openai
#   Downloading langchain_openai-1.1.12-py3-none-any.whl.metadata (3.1 kB)
# Requirement already satisfied: langchain-core<2.0.0,>=1.2.21 in d:\GenAI\MCQGEN\env\Lib\site-packages (from langchain-openai) (1.2.26)
# Requirement already satisfied: openai<3.0.0,>=2.26.0 in d:\GenAI\MCQGEN\env\Lib\site-packages (from langchain-openai) (2.30.0)
# Collecting tiktoken<1.0.0,>=0.7.0 (from langchain-openai)
#   Using cached tiktoken-0.12.0-cp311-cp311-win_amd64.whl.metadata (6.9 kB)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in d:\GenAI\MCQGEN\env\Lib\site-packages (from langchain-core<2.0.0,>=1.2.21->langchain-openai) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in d:\GenAI\MCQGEN\env\Lib\site-packages (from langchain-core<2.0.0,>=1.2.21->langchain-openai) (0.7.25)
# Requirement already satisfied: packaging>=23.2.0 in d:\GenAI\MCQGEN\env\Lib\site-packages (from langchain-core<2.0.0,>=1.2.21->langchain-openai) (26.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in d:\GenAI\MCQGEN\env\Lib\site-packages (from langchain-core<2.0.0,>=1.2.21->langchain-openai) (2.12.5)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in d:\GenAI\MCQGEN\env\Lib\site-packages (from langchain-core<2.0.0,>=1.2.21->langchain-openai) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in d:\GenAI\MCQGEN\env\Lib\site-packages (from langchain-core<2.0.0,>=1.2.21->langchain-openai) (9.1.4)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in d:\GenAI\MCQGEN\env\Lib\site-packages (from langchain-core<2.0.0,>=1.2.21->langchain-openai) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in d:\GenAI\MCQGEN\env\Lib\site-packages (from langchain-core<2.0.0,>=1.2.21->langchain-openai) (0.14.1)
# Requirement already satisfied: jsonpointer>=1.9 in d:\GenAI\MCQGEN\env\Lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.21->langchain-openai) (3.1.1)
# Requirement already satisfied: httpx<1,>=0.23.0 in d:\GenAI\MCQGEN\env\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.21->langchain-openai) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in d:\GenAI\MCQGEN\env\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.21->langchain-openai) (3.11.8)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in d:\GenAI\MCQGEN\env\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.21->langchain-openai) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in d:\GenAI\MCQGEN\env\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.21->langchain-openai) (2.33.1)
# Requirement already satisfied: xxhash>=3.0.0 in d:\GenAI\MCQGEN\env\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.21->langchain-openai) (3.6.0)
# Requirement already satisfied: zstandard>=0.23.0 in d:\GenAI\MCQGEN\env\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.21->langchain-openai) (0.25.0)
# Requirement already satisfied: anyio in d:\GenAI\MCQGEN\env\Lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.21->langchain-openai) (4.13.0)
# Requirement already satisfied: certifi in d:\GenAI\MCQGEN\env\Lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.21->langchain-openai) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in d:\GenAI\MCQGEN\env\Lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.21->langchain-openai) (1.0.9)
# Requirement already satisfied: idna in d:\GenAI\MCQGEN\env\Lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.21->langchain-openai) (3.11)
# Requirement already satisfied: h11>=0.16 in d:\GenAI\MCQGEN\env\Lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.21->langchain-openai) (0.16.0)
# Requirement already satisfied: distro<2,>=1.7.0 in d:\GenAI\MCQGEN\env\Lib\site-packages (from openai<3.0.0,>=2.26.0->langchain-openai) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in d:\GenAI\MCQGEN\env\Lib\site-packages (from openai<3.0.0,>=2.26.0->langchain-openai) (0.13.0)
# Requirement already satisfied: sniffio in d:\GenAI\MCQGEN\env\Lib\site-packages (from openai<3.0.0,>=2.26.0->langchain-openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in d:\GenAI\MCQGEN\env\Lib\site-packages (from openai<3.0.0,>=2.26.0->langchain-openai) (4.67.3)
# Requirement already satisfied: annotated-types>=0.6.0 in d:\GenAI\MCQGEN\env\Lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.21->langchain-openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in d:\GenAI\MCQGEN\env\Lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.21->langchain-openai) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in d:\GenAI\MCQGEN\env\Lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.21->langchain-openai) (0.4.2)
# Collecting regex>=2022.1.18 (from tiktoken<1.0.0,>=0.7.0->langchain-openai)
#   Downloading regex-2026.4.4-cp311-cp311-win_amd64.whl.metadata (41 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in d:\GenAI\MCQGEN\env\Lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.21->langchain-openai) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.26 in d:\GenAI\MCQGEN\env\Lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.21->langchain-openai) (2.6.3)
# Requirement already satisfied: colorama in d:\GenAI\MCQGEN\env\Lib\site-packages (from tqdm>4->openai<3.0.0,>=2.26.0->langchain-openai) (0.4.6)
# Downloading langchain_openai-1.1.12-py3-none-any.whl (88 kB)
# Using cached tiktoken-0.12.0-cp311-cp311-win_amd64.whl (879 kB)
# Downloading regex-2026.4.4-cp311-cp311-win_amd64.whl (278 kB)
# Installing collected packages: regex, tiktoken, langchain-openai
#
#    ---------------------------------------- 0/3 [regex]
#    -------------------------- ------------- 2/3 [langchain-openai]
#    -------------------------- ------------- 2/3 [langchain-openai]
#    -------------------------- ------------- 2/3 [langchain-openai]
#    ---------------------------------------- 3/3 [langchain-openai]
#
# Successfully installed langchain-openai-1.1.12 regex-2026.4.4 tiktoken-0.12.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import getpass
from langchain_openai import ChatOpenAI
from dotenv import load_dotenv
load_dotenv() ## Load environment variables from .env file
key = (os.getenv("OPENAI_API_KEY"))

# %%
llm = ChatOpenAI(model="gpt-4o-mini", temperature=0.9)
